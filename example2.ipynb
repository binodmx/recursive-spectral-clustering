# %% [markdown]
# # RecursiveSpectralClustering with Iris Dataset

# %%
from RecursiveSpectralClustering import RecursiveSpectralClustering
from sklearn import datasets 
import matplotlib.pyplot as plt 

# Load the iris dataset 
iris = datasets.load_iris() 
X = iris.data

# Perform spectral clustering 
clustering = RecursiveSpectralClustering(n_clusters=5) 
clustering.fit(X)

# Print the number of data points in each cluster
count = {}
for label in clustering.labels_:
    if label not in count:
        count[label] = 0
    count[label] += 1
print(count)

# Visualize the clusters 
plt.scatter(X[:, 0], X[:, 1], c=clustering.labels_) 
plt.ylabel('Feature 2') 
plt.xlabel('Feature 1') 
plt.show()
# Out:
# {0: 30, 1: 30, 2: 30, 3: 30, 4: 30}

# %%
from RecursiveSpectralClustering import RecursiveSpectralClustering
from sklearn import datasets 
import matplotlib.pyplot as plt 

# Load the iris dataset 
iris = datasets.load_iris() 
X = iris.data

# Perform spectral clustering 
clustering = RecursiveSpectralClustering(n_clusters=5) 
clustering.fit(X)

# Print the number of data points in each cluster
count = {}
for label in clustering.labels_:
    if label not in count:
        count[label] = 0
    count[label] += 1
print(count)

# Visualize the clusters 
plt.scatter(X[:, 0], X[:, 2], c=clustering.labels_) 
plt.ylabel('Feature 3') 
plt.xlabel('Feature 1') 
plt.show()
# Out:
# {0: 30, 1: 30, 2: 30, 3: 30, 4: 30}

# %%
from RecursiveSpectralClustering import RecursiveSpectralClustering
from sklearn import datasets 
import matplotlib.pyplot as plt 

# Load the iris dataset 
iris = datasets.load_iris() 
X = iris.data

# Perform spectral clustering 
clustering = RecursiveSpectralClustering(n_clusters=5) 
clustering.fit(X)

# Print the number of data points in each cluster
count = {}
for label in clustering.labels_:
    if label not in count:
        count[label] = 0
    count[label] += 1
print(count)

# Visualize the clusters 
plt.scatter(X[:, 0], X[:, 3], c=clustering.labels_) 
plt.ylabel('Feature 4') 
plt.xlabel('Feature 1') 
plt.show()
# Out:
# {0: 30, 1: 30, 2: 30, 3: 30, 4: 30}

# %%
from RecursiveSpectralClustering import RecursiveSpectralClustering
from sklearn import datasets 
import matplotlib.pyplot as plt 

# Load the iris dataset 
iris = datasets.load_iris() 
X = iris.data

# Perform spectral clustering 
clustering = RecursiveSpectralClustering(n_clusters=5) 
clustering.fit(X)

# Print the number of data points in each cluster
count = {}
for label in clustering.labels_:
    if label not in count:
        count[label] = 0
    count[label] += 1
print(count)

# Visualize the clusters 
plt.scatter(X[:, 1], X[:, 2], c=clustering.labels_) 
plt.ylabel('Feature 3') 
plt.xlabel('Feature 2') 
plt.show()
# Out:
# {0: 30, 1: 30, 2: 30, 3: 30, 4: 30}

# %%
from RecursiveSpectralClustering import RecursiveSpectralClustering
from sklearn import datasets 
import matplotlib.pyplot as plt 

# Load the iris dataset 
iris = datasets.load_iris() 
X = iris.data

# Perform spectral clustering 
clustering = RecursiveSpectralClustering(n_clusters=5) 
clustering.fit(X)

# Print the number of data points in each cluster
count = {}
for label in clustering.labels_:
    if label not in count:
        count[label] = 0
    count[label] += 1
print(count)

# Visualize the clusters 
plt.scatter(X[:, 1], X[:, 3], c=clustering.labels_) 
plt.ylabel('Feature 4') 
plt.xlabel('Feature 2') 
plt.show()
# Out:
# {0: 30, 1: 30, 2: 30, 3: 30, 4: 30}

# %%
from RecursiveSpectralClustering import RecursiveSpectralClustering
from sklearn import datasets 
import matplotlib.pyplot as plt 

# Load the iris dataset 
iris = datasets.load_iris() 
X = iris.data

# Perform spectral clustering 
clustering = RecursiveSpectralClustering(n_clusters=5) 
clustering.fit(X)

# Print the number of data points in each cluster
count = {}
for label in clustering.labels_:
    if label not in count:
        count[label] = 0
    count[label] += 1
print(count)

# Visualize the clusters 
plt.scatter(X[:, 2], X[:, 3], c=clustering.labels_) 
plt.ylabel('Feature 4') 
plt.xlabel('Feature 3') 
plt.show()
# Out:
# {0: 30, 1: 30, 2: 30, 3: 30, 4: 30}
